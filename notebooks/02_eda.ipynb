# %% [markdown]
# Business Questions
# Which vehicle characteristics have the greatest influence on the listing price of a used car?
# How do factors such as mileage, age, accident history, and horsepower affect a vehicle's listing price?
# Can a multiple linear regression model accurately estimate the listing price of a used vehicle based on its characteristics?
# Can the model identify vehicles whose asking price appears significantly higher or lower than the estimated market value?

# %%
import pandas as pd
df = pd.read_csv("../data/processed/used_cars_reduced.csv")
pd.set_option("display.float_format", "{:,.2f}".format)
# Out:
# C:\Users\casey\AppData\Local\Temp\ipykernel_46396\2660379681.py:2: DtypeWarning: Columns (0: dealer_zip) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/processed/used_cars_reduced.csv")

# %%
df.drop_duplicates(inplace = True)

# %%
df = df.reset_index()

# %%
df.shape
# Out:
# (2663251, 22)

# %%
df.columns
# Out:
# Index(['index', 'city', 'dealer_zip', 'engine_cylinders', 'engine_type',
#        'frame_damaged', 'fuel_type', 'has_accidents', 'horsepower', 'is_new',
#        'make_name', 'mileage', 'model_name', 'owner_count', 'price', 'salvage',
#        'seller_rating', 'transmission', 'trim_name', 'vehicle_damage_category',
#        'wheel_system', 'year'],
#       dtype='str')

# %%
df.tail()
# Out:
#            index       city dealer_zip engine_cylinders engine_type  \
# 2663246  3000035  Fairfield      94533               I4          I4
# 2663247  3000036    Vallejo      94591               V6          V6
# 2663248  3000037       Napa      94559              NaN         NaN
# 2663249  3000038  Fairfield      94533        I4 Diesel   I4 Diesel
# 2663250  3000039       Napa      94559               I4          I4
#
#         frame_damaged fuel_type has_accidents  horsepower  is_new  ...  \
# 2663246         False  Gasoline         False      170.00   False  ...
# 2663247           NaN  Gasoline           NaN      310.00    True  ...
# 2663248         False       NaN          True      240.00   False  ...
# 2663249         False    Diesel         False      180.00   False  ...
# 2663250         False  Gasoline         False      170.00   False  ...
#
#         model_name  owner_count     price  salvage  seller_rating  \
# 2663246    Equinox         1.00 17,998.00    False           4.27
# 2663247   Traverse          NaN 36,490.00      NaN           4.53
# 2663248     Fusion         2.00 12,990.00    False           4.14
# 2663249         XE         1.00 26,998.00    False           4.27
# 2663250      Rogue         1.00 19,900.00    False           4.33
#
#         transmission        trim_name vehicle_damage_category wheel_system  \
# 2663246            A      1.5T LT FWD                     NaN          FWD
# 2663247            A           LS FWD                     NaN          FWD
# 2663248            A               SE                     NaN          FWD
# 2663249            A  20d Premium AWD                     NaN          AWD
# 2663250            A    2017.5 SV FWD                     NaN          FWD
#
#          year
# 2663246  2018
# 2663247  2020
# 2663248  2016
# 2663249  2017
# 2663250  2017
#
# [5 rows x 22 columns]

# %%
df.dtypes
# Out:
# index                        int64
# city                           str
# dealer_zip                  object
# engine_cylinders               str
# engine_type                    str
# frame_damaged               object
# fuel_type                      str
# has_accidents               object
# horsepower                 float64
# is_new                        bool
# make_name                      str
# mileage                    float64
# model_name                     str
# owner_count                float64
# price                      float64
# salvage                     object
# seller_rating              float64
# transmission                   str
# trim_name                      str
# vehicle_damage_category    float64
# wheel_system                   str
# year                         int64
# dtype: object

# %%
df.isna().sum()
# Out:
# index                            0
# city                             0
# dealer_zip                       0
# engine_cylinders             87917
# engine_type                  87917
# frame_damaged              1096177
# fuel_type                    72638
# has_accidents              1096177
# horsepower                  150591
# is_new                           0
# make_name                        0
# mileage                     102516
# model_name                       0
# owner_count                1181157
# price                            0
# salvage                    1096177
# seller_rating                38300
# transmission                 55013
# trim_name                   103002
# vehicle_damage_category    2663251
# wheel_system                128034
# year                             0
# dtype: int64

# %%
df.shape
# Out:
# (2663251, 22)

# %%
df.describe()
# Out:
#              index   horsepower       mileage  owner_count        price  \
# count 2,663,251.00 2,512,660.00  2,560,735.00 1,482,094.00 2,663,251.00
# mean  1,492,757.99       251.67     34,730.86         1.53    29,724.89
# std     862,007.48        91.03     77,967.58         0.92    20,251.10
# min           0.00        55.00          0.00         1.00       165.00
# 25%     749,003.50       176.00          9.00         1.00    17,681.00
# 50%   1,489,415.00       248.00     17,880.00         1.00    26,000.00
# 75%   2,230,800.50       305.00     49,241.00         2.00    38,290.00
# max   3,000,039.00     1,001.00 99,999,988.00        19.00 3,299,995.00
#
#        seller_rating  vehicle_damage_category         year
# count   2,624,951.00                     0.00 2,663,251.00
# mean            4.28                      NaN     2,017.43
# std             0.51                      NaN         4.34
# min             1.00                      NaN     1,915.00
# 25%             4.03                      NaN     2,017.00
# 50%             4.35                      NaN     2,019.00
# 75%             4.62                      NaN     2,020.00
# max             5.00                      NaN     2,021.00

# %%
df.head()
# Out:
#    index      city dealer_zip engine_cylinders engine_type frame_damaged  \
# 0      0   Bayamon        960               I4          I4           NaN
# 1      1  San Juan        922               I4          I4           NaN
# 2      2  Guaynabo        969               H4          H4         False
# 3      3  San Juan        922               V6          V6           NaN
# 4      4  San Juan        922               I4          I4           NaN
#
#   fuel_type has_accidents  horsepower  is_new  ...       model_name  \
# 0  Gasoline           NaN      177.00    True  ...         Renegade
# 1  Gasoline           NaN      246.00    True  ...  Discovery Sport
# 2  Gasoline         False      305.00   False  ...          WRX STI
# 3  Gasoline           NaN      340.00    True  ...        Discovery
# 4  Gasoline           NaN      246.00    True  ...  Discovery Sport
#
#    owner_count     price  salvage  seller_rating transmission     trim_name  \
# 0          NaN 23,141.00      NaN           2.80            A  Latitude FWD
# 1          NaN 46,500.00      NaN           3.00            A         S AWD
# 2         3.00 46,995.00    False            NaN            M          Base
# 3          NaN 67,430.00      NaN           3.00            A    V6 HSE AWD
# 4          NaN 48,880.00      NaN           3.00            A         S AWD
#
#   vehicle_damage_category wheel_system  year
# 0                     NaN          FWD  2019
# 1                     NaN          AWD  2020
# 2                     NaN          AWD  2016
# 3                     NaN          AWD  2020
# 4                     NaN          AWD  2020
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2663251 entries, 0 to 2663250
# Data columns (total 22 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   index                    int64
#  1   city                     str
#  2   dealer_zip               object
#  3   engine_cylinders         str
#  4   engine_type              str
#  5   frame_damaged            object
#  6   fuel_type                str
#  7   has_accidents            object
#  8   horsepower               float64
#  9   is_new                   bool
#  10  make_name                str
#  11  mileage                  float64
#  12  model_name               str
#  13  owner_count              float64
#  14  price                    float64
#  15  salvage                  object
#  16  seller_rating            float64
#  17  transmission             str
#  18  trim_name                str
#  19  vehicle_damage_category  float64
#  20  wheel_system             str
#  21  year                     int64
# dtypes: bool(1), float64(6), int64(2), object(4), str(9)
# memory usage: 429.2+ MB

# %%
df.drop("vehicle_damage_category", axis=1, inplace=True)

# %%
numerical_data = df.select_dtypes(include=["number"]).columns.tolist()
categorical_data = df.select_dtypes(include=["object", "string", "bool"]).columns.tolist()

# %%
numerical_data
# Out:
# ['index',
#  'horsepower',
#  'mileage',
#  'owner_count',
#  'price',
#  'seller_rating',
#  'year']

# %%
categorical_data
# Out:
# ['city',
#  'dealer_zip',
#  'engine_cylinders',
#  'engine_type',
#  'frame_damaged',
#  'fuel_type',
#  'has_accidents',
#  'is_new',
#  'make_name',
#  'model_name',
#  'salvage',
#  'transmission',
#  'trim_name',
#  'wheel_system']

# %% [markdown]
# Data Cleaning Candidates", and add:
#
# 1.Drop all duplicates
# 2. Remove vehicle_damage_category (100% missing).
# 3.Investigate or treat implausible mileage values (>1,000,000).
# 4.Investigate missing values in frame_damaged, has_accidents, salvage, and owner_count.
# 5.Does dealer_zip add meaningful information beyond city, or is it mostly redundant?
# are engine cylinder matching engine-type?
# 6.Later, during feature engineering, ill group infrequent trims because thousands of unique categories can be difficult for a simple linear regression model.
# 7.Drop engine cylinders because it is identical to engine type
# 8.

# %%
df[numerical_data].describe()
# Out:
#              index   horsepower       mileage  owner_count        price  \
# count 2,663,251.00 2,512,660.00  2,560,735.00 1,482,094.00 2,663,251.00
# mean  1,492,757.99       251.67     34,730.86         1.53    29,724.89
# std     862,007.48        91.03     77,967.58         0.92    20,251.10
# min           0.00        55.00          0.00         1.00       165.00
# 25%     749,003.50       176.00          9.00         1.00    17,681.00
# 50%   1,489,415.00       248.00     17,880.00         1.00    26,000.00
# 75%   2,230,800.50       305.00     49,241.00         2.00    38,290.00
# max   3,000,039.00     1,001.00 99,999,988.00        19.00 3,299,995.00
#
#        seller_rating         year
# count   2,624,951.00 2,663,251.00
# mean            4.28     2,017.43
# std             0.51         4.34
# min             1.00     1,915.00
# 25%             4.03     2,017.00
# 50%             4.35     2,019.00
# 75%             4.62     2,020.00
# max             5.00     2,021.00

# %%
df[df["mileage"] == df["mileage"].max()]
# Out:
#            index     city dealer_zip engine_cylinders engine_type  \
# 2242507  2514282  Houston      77065        I6 Diesel   I6 Diesel
#
#         frame_damaged fuel_type has_accidents  horsepower  is_new  ...  \
# 2242507           NaN    Diesel           NaN         NaN    True  ...
#
#               mileage    model_name owner_count     price  salvage  \
# 2242507 99,999,988.00  3500 Chassis         NaN 52,610.00      NaN
#
#         seller_rating  transmission trim_name wheel_system  year
# 2242507          3.57             A       NaN          NaN  2019
#
# [1 rows x 21 columns]

# %%
#Several extremely large mileage values (e.g., 1,111,111 and 99,999,988) appear to be placeholder or #
#erroneous values rather than genuine odometer readings. 
#Further investigation or consultation of the dataset documentation is recommended before deciding how to treat these records.
df[df["mileage"] > 1_000_000]
# Out:
#            index       city dealer_zip engine_cylinders engine_type  \
# 185063    210044   Nappanee      46550               V8          V8
# 1180953  1319359  Belleview      34420               V6          V6
# 1853005  2072522      Boise      83713               V8          V8
# 1853098  2072617      Boise      83713               I4          I4
# 1853986  2073566      Boise      83713               V8          V8
# 1855598  2075306      Boise      83713               I4          I4
# 2242507  2514282    Houston      77065        I6 Diesel   I6 Diesel
#
#         frame_damaged fuel_type has_accidents  horsepower  is_new  ...  \
# 185063            NaN  Gasoline           NaN      355.00    True  ...
# 1180953           NaN  Gasoline           NaN      375.00    True  ...
# 1853005           NaN  Gasoline           NaN      355.00    True  ...
# 1853098           NaN  Gasoline           NaN      170.00    True  ...
# 1853986           NaN  Gasoline           NaN      355.00    True  ...
# 1855598           NaN  Gasoline           NaN      237.00    True  ...
# 2242507           NaN    Diesel           NaN         NaN    True  ...
#
#               mileage      model_name owner_count     price  salvage  \
# 185063   4,290,461.00  Silverado 1500         NaN 50,775.00      NaN
# 1180953  1,225,238.00           F-150         NaN 45,149.00      NaN
# 1853005  1,111,111.00  Silverado 1500         NaN 39,523.00      NaN
# 1853098  1,111,111.00         Equinox         NaN 23,620.00      NaN
# 1853986  1,111,111.00  Silverado 1500         NaN 41,420.00      NaN
# 1855598  1,111,111.00             XT5         NaN 45,970.00      NaN
# 2242507 99,999,988.00    3500 Chassis         NaN 52,610.00      NaN
#
#         seller_rating  transmission          trim_name wheel_system  year
# 185063           5.00             A    LT Crew Cab 4WD          4WD  2020
# 1180953          4.50             A  XLT SuperCrew RWD          4X2  2020
# 1853005          3.82             A  LT Double Cab 4WD          4WD  2020
# 1853098          3.82             A        1.5T LT AWD          4WD  2020
# 1853986          3.82             A  LT Double Cab 4WD          4WD  2020
# 1855598          3.82             A         Luxury AWD          4WD  2020
# 2242507          3.57             A                NaN          NaN  2019
#
# [7 rows x 21 columns]

# %% [markdown]
# Seven records contain implausibly large mileage values (>1,000,000). Several share identical values (e.g., 1,111,111), suggesting placeholder or erroneous entries rather than genuine odometer readings. These records will require special treatment during data cleaning.

# %%
df[df["owner_count"]  > 10]
# Out:
#            index           city dealer_zip engine_cylinders engine_type  \
# 39261      44751           Lodi       7644               V8          V8
# 50831      57580     Bloomfield       7003               V8          V8
# 67287      75922         Macomb      48042               V8          V8
# 94271     106661     Somerville       2143               I5          I5
# 172760    195450         Warsaw      46582               I4          I4
# ...          ...            ...        ...              ...         ...
# 2535149  2850569  Spring Valley      91977               I6          I6
# 2552437  2870450    Canoga Park      91303               I4          I4
# 2623307  2953461      Sunnyvale      94085               I4          I4
# 2632136  2963675    Santa Clara      95051               I4          I4
# 2633905  2965812        Fremont      94536               I6          I6
#
#         frame_damaged fuel_type has_accidents  horsepower  is_new  ...  \
# 39261           False  Gasoline         False      170.00   False  ...
# 50831           False  Gasoline         False      300.00   False  ...
# 67287           False  Gasoline         False      180.00   False  ...
# 94271           False  Gasoline         False      168.00   False  ...
# 172760          False  Gasoline         False      115.00   False  ...
# ...               ...       ...           ...         ...     ...  ...
# 2535149         False  Gasoline         False      181.00   False  ...
# 2552437         False  Gasoline          True      115.00   False  ...
# 2623307         False  Gasoline         False      122.00   False  ...
# 2632136         False  Gasoline         False      126.00   False  ...
# 2633905         False  Gasoline         False      208.00   False  ...
#
#            mileage   model_name owner_count     price  salvage seller_rating  \
# 39261   104,655.00     Brougham       12.00  3,995.00    False          3.89
# 50831   203,000.00        F-150       11.00  7,999.00    False          4.56
# 67287    46,965.00  Monte Carlo       15.00 24,990.00    False          4.76
# 94271   193,131.00          S40       11.00  3,995.00    False          4.45
# 172760  157,225.00       Beetle       11.00  4,999.00    False          4.62
# ...            ...          ...         ...       ...      ...           ...
# 2535149 109,000.00     Wrangler       11.00 12,995.00    False          5.00
# 2552437 202,356.00  Civic Coupe       11.00  1,999.00    False          4.00
# 2623307 102,700.00        Versa       11.00  5,500.00    False           NaN
# 2632136 143,112.00     Wrangler       11.00  8,999.00    False          4.50
# 2633905 238,744.00     5 Series       16.00  5,500.00    False          4.00
#
#          transmission            trim_name wheel_system  year
# 39261               A                  RWD          RWD  1991
# 50831               A  FX4 Ext. Cab SB 4WD          4WD  2004
# 67287               A               SS RWD          RWD  1987
# 94271               M                 2.4i          FWD  2005
# 172760            NaN   2 Dr GLS Hatchback          FWD  1999
# ...               ...                  ...          ...   ...
# 2535149             A                Sport          4WD  1998
# 2552437             A                   LX          FWD  2001
# 2623307             A                S 1.8          FWD  2009
# 2632136             M                    S          4WD  1991
# 2633905             M       535i Sedan RWD          RWD  1991
#
# [128 rows x 21 columns]

# %% [markdown]
# Owner count exhibits a negative association with vehicle price and a positive association with mileage. Vehicles with more previous owners also tend to be older, suggesting that owner count is correlated with both vehicle age and usage. The feature appears informative and will be retained for model training, while recognizing that its effect may overlap with other predictors such as year and mileage.

# %%
df["owner_count"].value_counts().sort_index()
# Out:
# owner_count
# 1.00     972156
# 2.00     330478
# 3.00     116768
# 4.00      39764
# 5.00      14207
# 6.00       5286
# 7.00       1977
# 8.00        836
# 9.00        366
# 10.00       128
# 11.00        73
# 12.00        21
# 13.00        16
# 14.00         7
# 15.00         6
# 16.00         3
# 18.00         1
# 19.00         1
# Name: count, dtype: int64

# %%
df["owner_count"].isna().sum()
# Out:
# np.int64(1181157)

# %%
df[df["owner_count"] == 19]
# Out:
#          index         city dealer_zip engine_cylinders engine_type  \
# 859385  962449  Mt Sterling      40353               V8          V8
#
#        frame_damaged fuel_type has_accidents  horsepower  is_new  ...  \
# 859385         False  Gasoline          True      220.00   False  ...
#
#           mileage  model_name owner_count    price  salvage seller_rating  \
# 859385 126,611.00    RAM 1500       19.00 3,694.00    False          4.22
#
#         transmission trim_name wheel_system  year
# 859385             A    LT 4WD          4WD  1997
#
# [1 rows x 21 columns]

# %%
df.groupby("owner_count")["price"].mean()
# Out:
# owner_count
# 1.00    25,225.62
# 2.00    17,941.32
# 3.00    14,317.36
# 4.00    12,710.21
# 5.00    12,016.20
# 6.00    12,050.94
# 7.00    13,296.37
# 8.00    11,726.27
# 9.00    13,394.89
# 10.00   10,739.07
# 11.00   10,024.23
# 12.00    5,798.00
# 13.00    7,630.50
# 14.00   12,681.43
# 15.00   10,176.50
# 16.00   10,774.67
# 18.00    6,999.00
# 19.00    3,694.00
# Name: price, dtype: float64

# %%
df.groupby("owner_count")["mileage"].mean()
# Out:
# owner_count
# 1.00     41,882.28
# 2.00     81,649.54
# 3.00    105,846.50
# 4.00    121,851.00
# 5.00    132,584.19
# 6.00    139,110.61
# 7.00    141,454.55
# 8.00    144,748.62
# 9.00    151,364.29
# 10.00   146,067.66
# 11.00   156,307.33
# 12.00   155,633.69
# 13.00   196,052.38
# 14.00   119,815.17
# 15.00   180,124.60
# 16.00   244,811.67
# 18.00   211,192.00
# 19.00   126,611.00
# Name: mileage, dtype: float64

# %%
df.groupby("owner_count")["year"].mean()
# Out:
# owner_count
# 1.00    2,017.07
# 2.00    2,013.85
# 3.00    2,011.30
# 4.00    2,009.16
# 5.00    2,007.19
# 6.00    2,005.50
# 7.00    2,003.96
# 8.00    2,002.79
# 9.00    2,001.91
# 10.00   2,000.38
# 11.00   1,999.11
# 12.00   1,998.38
# 13.00   1,997.19
# 14.00   1,994.00
# 15.00   1,995.50
# 16.00   1,994.67
# 18.00   1,995.00
# 19.00   1,997.00
# Name: year, dtype: float64

# %%
df[numerical_data].corr()
# Out:
#                index  horsepower  mileage  owner_count  price  seller_rating  \
# index           1.00        0.03    -0.01         0.01   0.03           0.00
# horsepower      0.03        1.00    -0.05         0.00   0.60           0.05
# mileage        -0.01       -0.05     1.00         0.52  -0.28           0.01
# owner_count     0.01        0.00     0.52         1.00  -0.23           0.01
# price           0.03        0.60    -0.28        -0.23   1.00           0.06
# seller_rating   0.00        0.05     0.01         0.01   0.06           1.00
# year            0.03        0.06    -0.46        -0.59   0.37          -0.04
#
#                year
# index          0.03
# horsepower     0.06
# mileage       -0.46
# owner_count   -0.59
# price          0.37
# seller_rating -0.04
# year           1.00

# %%
df[numerical_data].skew()
# Out:
# index             0.01
# horsepower        0.67
# mileage         823.52
# owner_count       2.47
# price            14.78
# seller_rating    -1.54
# year             -4.43
# dtype: float64

# %%
df[categorical_data].describe()
# Out:
#            city  dealer_zip engine_cylinders engine_type frame_damaged  \
# count   2663251     2663251          2575334     2575334       1567074
# unique     4687       10411               39          39             2
# top     Houston       77477               I4          I4         False
# freq      37446        7058          1216031     1216031       1552123
#
#        fuel_type has_accidents   is_new make_name model_name  salvage  \
# count    2590613       1567074  2663251   2663251    2663251  1567074
# unique         8             2        2       100       1429        2
# top     Gasoline         False    False      Ford      F-150    False
# freq     2297701       1324168  1527324    442252     119058  1556555
#
#        transmission trim_name wheel_system
# count       2608238   2560249      2535217
# unique            4      9062            5
# top               A    SE FWD          FWD
# freq        2193284     72751      1082600

# %% [markdown]
# engine_type and engine_cylinders contain identical information, including matching missing values (.equals() returned True). Therefore, engine_cylinders is redundant and can be removed during feature engineering to eliminate duplicate information.

# %%
(df["engine_type"] == df["engine_cylinders"]).all()
# Out:
# np.False_

# %%
df[df["engine_type"] != df["engine_cylinders"]]
# Out:
#            index       city dealer_zip engine_cylinders engine_type  \
# 42            42      Bronx      10466              NaN         NaN
# 50            50      Bronx      10466              NaN         NaN
# 61            61      Bronx      10466              NaN         NaN
# 112          112      Bronx      10466              NaN         NaN
# 215          217      Bronx      10466              NaN         NaN
# ...          ...        ...        ...              ...         ...
# 2663086  2999874  Fairfield      94533              NaN         NaN
# 2663094  2999882      Ukiah      95482              NaN         NaN
# 2663131  2999919  Fairfield      94533              NaN         NaN
# 2663161  2999949  Fairfield      94533              NaN         NaN
# 2663248  3000037       Napa      94559              NaN         NaN
#
#         frame_damaged fuel_type has_accidents  horsepower  is_new  ...  \
# 42              False       NaN         False      180.00   False  ...
# 50              False       NaN         False         NaN   False  ...
# 61              False       NaN         False      283.00   False  ...
# 112             False       NaN         False      360.00   False  ...
# 215             False       NaN         False      395.00   False  ...
# ...               ...       ...           ...         ...     ...  ...
# 2663086         False  Electric         False         NaN   False  ...
# 2663094         False  Electric          True         NaN   False  ...
# 2663131         False  Electric         False         NaN   False  ...
# 2663161         False  Electric         False         NaN   False  ...
# 2663248         False       NaN          True      240.00   False  ...
#
#           mileage      model_name owner_count     price  salvage  \
# 42      15,778.00        Renegade        1.00 16,200.00    False
# 50      19,801.00         Impreza        1.00 17,300.00    False
# 61      57,995.00             200        3.00  6,500.00    False
# 112     42,942.00  Grand Cherokee        1.00 33,700.00    False
# 215     38,602.00            1500        2.00 48,700.00    False
# ...           ...             ...         ...       ...      ...
# 2663086 31,540.00         Bolt EV        1.00 17,998.00    False
# 2663094 33,921.00         Bolt EV        1.00 19,479.00    False
# 2663131 14,247.00            LEAF        1.00  9,599.00    False
# 2663161 15,588.00            LEAF        1.00  9,599.00    False
# 2663248 57,992.00          Fusion        2.00 12,990.00    False
#
#         seller_rating  transmission                      trim_name  \
# 42               2.80             A                   Altitude 4WD
# 50               2.80           CVT         2.0i Touring Wagon AWD
# 61               2.80             A              Touring Sedan FWD
# 112              2.80             A                  Trailhawk 4WD
# 215              2.80             A  Laramie Longhorn Crew Cab 4WD
# ...               ...           ...                            ...
# 2663086          4.27             A                    Premier FWD
# 2663094          4.53             A                    Premier FWD
# 2663131          4.27             A                              S
# 2663161          4.27             A                              S
# 2663248          4.14             A                             SE
#
#         wheel_system  year
# 42               4WD  2017
# 50               NaN  2018
# 61               FWD  2013
# 112              4WD  2019
# 215              4WD  2019
# ...              ...   ...
# 2663086          FWD  2017
# 2663094          FWD  2017
# 2663131          FWD  2016
# 2663161          FWD  2016
# 2663248          FWD  2016
#
# [87917 rows x 21 columns]

# %%
df["engine_type"].equals (df["engine_cylinders"])
# Out:
# True

# %%
df['salvage']
# Out:
# 0            NaN
# 1            NaN
# 2          False
# 3            NaN
# 4            NaN
#            ...
# 2663246    False
# 2663247      NaN
# 2663248    False
# 2663249    False
# 2663250    False
# Name: salvage, Length: 2663251, dtype: object

# %%
df["salvage"].value_counts(dropna=False)
# Out:
# salvage
# False    1556555
# NaN      1096177
# True       10519
# Name: count, dtype: int64

# %%
df.groupby("salvage")["price"].mean()
# Out:
# salvage
# False   23,215.90
# True    13,737.68
# Name: price, dtype: float64

# %%
df.groupby("has_accidents")["price"].mean()
# Out:
# has_accidents
# False   24,300.46
# True    16,893.12
# Name: price, dtype: float64

# %%
df["has_accidents"].value_counts(dropna=False)
# Out:
# has_accidents
# False    1324168
# NaN      1096177
# True      242906
# Name: count, dtype: int64
